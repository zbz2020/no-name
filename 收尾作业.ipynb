# %%
from PIL import Image
import matplotlib.pyplot as plt 
img=PIL.Image.open('test.png')

# %%
img= img.rotate(30) 
plt.imshow(img)

# %%
#判断闰年平年
def runnian(year):    
    if year%4==0 and year%400==0:
        return 366
    elif year%4==0 and year%100!=0:
        return 366
    else:
        return 365

# %%
# Out:
#   File "<ipython-input-78-d3342cba5189>", line 1
#     print years
#               ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(years)?
